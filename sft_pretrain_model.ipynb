# %% [markdown]
# # **Training a Conversational Model using SFTTrainer**
#
# The SFTTrainer from the TRL (Transformers Reinforcement Learning) library is a powerful tool used for supervised fine-tuning of language models. It enables developers and researchers to refine pre-trained Large Language Models (LLMs) using task-specific datasets in order to improve their performance for targeted applications such as conversational AI, question answering, summarization, and instruction-following systems.
#
# In this notebook, we will explore how to train a conversational model using the **SFTTrainer** framework together with the Hugging Face Transformers ecosystem. Instead of building a language model from scratch, supervised fine-tuning allows us to adapt an already pre-trained model to better understand and generate human-like conversations.
#
# The notebook will guide us through the complete fine-tuning pipeline, including:
# - Loading a pre-trained conversational model
# - Preparing and tokenizing a dialogue dataset
# - Configuring training parameters
# - Training the model using SFTTrainer
# - Evaluating the model’s conversational responses
#
# By completing this exercise, we will gain hands-on experience with modern transformer-based conversational AI training workflows and understand how supervised fine-tuning is applied in real-world natural language processing applications.

# %%
import os
os.environ["PYTHONUTF8"] = "1"

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, DataCollatorForLanguageModeling
from trl import SFTTrainer
from trl.trainer import SFTConfig

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cu126
# True

# %%
dataset = load_dataset("timdettmers/openassistant-guanaco")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Repo card metadata block was not found. Setting CardData to empty.

# %%
dataset_train = dataset['train']
dataset_train[0]
# Out:
# {'text': '### Human: Can you write a short introduction about the relevance of the term "monopsony" in economics? Please use examples related to potential monopsonies in the labour market and cite relevant research.### Assistant: "Monopsony" refers to a market structure where there is only one buyer for a particular good or service. In economics, this term is particularly relevant in the labor market, where a monopsony employer has significant power over the wages and working conditions of their employees. The presence of a monopsony can result in lower wages and reduced employment opportunities for workers, as the employer has little incentive to increase wages or provide better working conditions.\n\nRecent research has identified potential monopsonies in industries such as retail and fast food, where a few large companies control a significant portion of the market (Bivens & Mishel, 2013). In these industries, workers often face low wages, limited benefits, and reduced bargaining power, leading to a situation where they are dependent on the employer for their livelihood. This dependence can result in further suppression of wages and a decline in working conditions.\n\nOverall, the concept of monopsony is essential to understanding the dynamics of labor markets and the impact of market power on workers. Further research is needed to understand the extent and impact of monopsonies on the economy and to develop policies to address this issue.\n\nReferences:\nBivens, J., & Mishel, L. (2013). The Pay of Corporate Executives and Financial Professionals as Evidence of Rents in Top 1 Percent Incomes. Journal of Economic Perspectives, 27(3), 57-78.### Human: Now explain it to a dog'}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device.type
# Out:
# 'cuda'

# %%
model = AutoModelForCausalLM.from_pretrained("facebook/opt-350m")
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-350m")

model.to(device)
# Out:
# Loading weights: 100%|██████████| 388/388 [00:00<00:00, 16163.98it/s]
# OPTForCausalLM(
#   (model): OPTModel(
#     (decoder): OPTDecoder(
#       (embed_tokens): Embedding(50272, 512, padding_idx=1)
#       (embed_positions): OPTLearnedPositionalEmbedding(2050, 1024)
#       (project_out): Linear(in_features=1024, out_features=512, bias=False)
#       (project_in): Linear(in_features=512, out_features=1024, bias=False)
#       (layers): ModuleList(
#         (0-23): 24 x OPTDecoderLayer(
#           (self_attn): OPTAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=512, out_features=50272, bias=False)
# )

# %% [markdown]
# ### **Data Collator**

# %%
### in modern LLM fine tuning we dont use collator function anymore

# %% [markdown]
# #### **SFT Config, SFT Trainer**

# %%
training_args = SFTConfig(
    output_dir="/tmp",
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=10,
    save_strategy='epoch',
    max_length=1024,
    do_eval=True
)

# %%
trainer = SFTTrainer(
    model= model,
    args=training_args,
    train_dataset=dataset_train,
    processing_class=tokenizer
)

# %%
## train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='51' max='49230' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   51/49230 07:59 < 133:38:33, 0.10 it/s, Epoch 0.01/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1118.906738</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1257.156250</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 ## train the model
# ----> 2 trainer.train()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\trainer.py:1427, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1425 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1426 with ctx:
# -> 1427     return inner_training_loop(
#    1428         args=args,
#    1429         resume_from_checkpoint=resume_from_checkpoint,
#    1430         trial=trial,
#    1431         ignore_keys_for_eval=ignore_keys_for_eval,
#    1432     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\trainer.py:1509, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1507 for epoch in range(epochs_trained, num_train_epochs):
#    1508     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1509     self._run_epoch(
#    1510         model=model,
#    1511         epoch=epoch,
#    1512         train_dataloader=train_dataloader,
#    1513         steps_in_epoch=steps_in_epoch,
#    1514         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1515         trial=trial,
#    1516         ignore_keys_for_eval=ignore_keys_for_eval,
#    1517         start_time=start_time,
#    1518         resume_from_checkpoint=resume_from_checkpoint,
#    1519         epochs_trained=epochs_trained,
#    1520         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1521     )
#    1522     if self.control.should_training_stop:
#    1523         break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\trainer.py:1753, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1748         raise ValueError(
#    1749             f"Calculated loss must be on the original device: {self._tr_loss.device} but device in use is {tr_loss_step.device}"
#    1750         )
#    1751     self._tr_loss += tr_loss_step
# -> 1753 self.current_flos += float(self.floating_point_ops(inputs))
#    1754 self._track_num_input_tokens(inputs)
#    1756 if do_sync_step:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\trainer.py:3886, in Trainer.floating_point_ops(self, inputs)
#    3883         self.state.total_flos += self.current_flos
#    3884         self.current_flos = 0
# -> 3886 def floating_point_ops(self, inputs: dict[str, torch.Tensor | Any]) -> int:
#    3887     """
#    3888     For models that inherit from [`PreTrainedModel`], uses that method to compute the number of floating point
#    3889     operations for every backward + forward pass. If using another model, either implement such a method in the
#    (...)   3897         `int`: The number of floating-point operations.
#    3898     """
#    3899     if (main_input := getattr(self.model, "main_input_name", "input_ids")) in inputs and hasattr(
#    3900         self.model, "num_parameters"
#    3901     ):
#
# KeyboardInterrupt:
